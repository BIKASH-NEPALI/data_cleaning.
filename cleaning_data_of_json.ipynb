# %%
import json

# %%
def load_data(file_name): 
    with open(file_name,"r") as f: 
        data=json.load(f) 
    return data

# %%
data=load_data("data2.json")
print(data)
# Out:
# {'users': [{'id': 1, 'name': 'Amit', 'friends': [2, 3], 'liked_pages': [101]}, {'id': 2, 'name': 'Priya', 'friends': [1, 4], 'liked_pages': [102]}, {'id': 3, 'name': 'Rahul', 'friends': [1], 'liked_pages': [101, 103]}, {'id': 4, 'name': 'Sara', 'friends': [2], 'liked_pages': [104]}], 'pages': [{'id': 101, 'name': 'Python Developers'}, {'id': 102, 'name': 'Data Science Enthusiasts'}, {'id': 103, 'name': 'AI & ML Community'}, {'id': 104, 'name': 'Web Dev Hub'}]}

# %%
new_data=clean_data(data)
print(new_data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 new_data=clean_data(data)
#       2 print(new_data)
#
# Cell In[37], line 6, in clean_data(data)
#       1 def clean_data(data):
#       2     # remove users with missing names:
#       3     #for user in data["users"]:
#       4         #print(user["name"])
#       5     for user in data :
# ----> 6         user["name"]=user["name"].strip()
#       9     return data
#
# TypeError: string indices must be integers, not 'str'

# %%
json.dump(new_data,open("data2.json","w") , indent=4)
print("data has been cleaend succesfully")
# Out:
# data has been cleaend succesfully
