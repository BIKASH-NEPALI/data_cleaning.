# %%
import json

# %%
def accesing_data(variable):
    with open(variable, "r") as sort:
        data =json.load(sort)
    return data

# %%
val=accesing_data("data2.json")
print(val)
# Out:
# {'name': 'Alice', 'age': 25, 'is_student': True, 'courses': ['Math', 'Physics', 'C Programming'], 'address': {'city': 'Amsterdam', 'country': 'Netherlands'}}

# %%
# Out:
#   Cell In[21], line 1
#     print(value(name)
#                      ^
# _IncompleteInputError: incomplete input
